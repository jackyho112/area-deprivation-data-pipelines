# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
header = pd.read_csv('./ams/2020/202001201500/ams__header_2020__202001201500.csv')
bill_info = pd.read_csv('./ams/2020/202001201500/ams__billgen_2020__202001201500.csv')
cargo_desc = pd.read_csv('./ams/2020/202001201500/ams__cargodesc_2020__202001201500.csv')
cosignee = pd.read_csv('./ams/2020/202001201500/ams__consignee_2020__202001201500.csv')
container = pd.read_csv('./ams/2020/202001201500/ams__container_2020__202001201500.csv')
hazmat = pd.read_csv('./ams/2020/202001201500/ams__hazmat_2020__202001201500.csv')
hazmat_class = pd.read_csv('./ams/2020/202001201500/ams__hazmatclass_2020__202001201500.csv')
mark_number = pd.read_csv('./ams/2020/202001201500/ams__marksnumbers_2020__202001201500.csv')
notified_party = pd.read_csv('./ams/2020/202001201500/ams__notifyparty_2020__202001201500.csv')
shipper = pd.read_csv('./ams/2020/202001201500/ams__shipper_2020__202001201500.csv')
tariff = pd.read_csv('./ams/2020/202001201500/ams__tariff_2020__202001201500.csv')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (25,26) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
header
# Out:
#            identifier carrier_code vessel_country_code  \
# 0           202001060         SWOE                  US
# 1           202001061         SWOE                  US
# 2           202001062         OOLU                  SG
# 3           202001063         OOLU                  SG
# 4           202001064         OOLU                  TW
# ...               ...          ...                 ...
# 986072  2020011458712         CHSL                  PA
# 986073  2020011458713         MXWI                  MT
# 986074  2020011458714         ABFB                  HK
# 986075  2020011458715         SSNF                  FR
# 986076  2020011458716         APLU                  HK
#
#                     vessel_name         port_of_unlading  \
# 0          PRESIDENT EISENHOWER      Oakland, California
# 1          PRESIDENT EISENHOWER      Oakland, California
# 2               THALASSA ELPIDA        Savannah, Georgia
# 3               THALASSA ELPIDA        Savannah, Georgia
# ...

# %%
header.identifier.unique().size
# Out:
# 986077

# %%
header.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986077 entries, 0 to 986076
# Data columns (total 34 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   identifier                             986077 non-null  int64
#  1   carrier_code                           986077 non-null  object
#  2   vessel_country_code                    986041 non-null  object
#  3   vessel_name                            986077 non-null  object
#  4   port_of_unlading                       986077 non-null  object
#  5   estimated_arrival_date                 986077 non-null  object
#  6   foreign_port_of_lading_qualifier       986077 non-null  object
#  7   foreign_port_of_lading                 986077 non-null  object
#  8   manifest_quantity                      986077 non-null  int64
#  9   manifest_unit                          986077 non-null  object
# ...

# %% [markdown]
# Columns to keep for each lading header:
#
# - identifier @int
# - carrier_code @str
# - vessel_country_code @str
# - vessel_name @str
# - port_of_unlading @str
# - estimated_arrival_date @date
# - foreign_port_of_lading_qualifier @str
# - foreign_port_of_lading @str
# - manifest_quantity @int
# - manifest_unit @str
# - weight @int
# - weight_unit @str
# - record_status_indicator @str
# - place_of_receipt @str
# - port_of_destination @str
# - foreign_port_of_destination_qualifier @str
# - foreign_port_of_destination @str
# - conveyance_id_qualifier @str
# - conveyance_id @str
# - mode_of_transportation @str
# - actual_arrival_date @date
#
# identifier will be the primary key

# %%
bill_info
# Out:
#            identifier master_bol_number  house_bol_number  \
# 0           202001060    APLUSHBW014713  SWOESH1S01451870
# 1           202001061    APLUSHBW014714  SWOESH1S01451855
# 2           202001062    OOLU2107899100               NaN
# 3           202001063    OOLU2107932870               NaN
# 4           202001064    OOLU2107974500               NaN
# ...               ...               ...               ...
# 986072  2020011458712    COSU6213352080  CHSLINA22001053A
# 986073  2020011458713  EGLV142954552441    MXWISH19120048
# 986074  2020011458714  ONEYSH9FVF806700   ABFBSHA91214876
# 986075  2020011458715    COSU6229303200  SSNFSPSH20011005
# 986076  2020011458716    APLUAXK0228420               NaN
#
#         sub_house_bol_number voyage_number bill_type_code  manifest_number  \
# 0                        NaN         0DB4P     House Bill              1.0
# 1                        NaN         0DB4P     House Bill              1.0
# ...

# %%
bill_info.identifier.unique().size
# Out:
# 986077

# %%
bill_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986077 entries, 0 to 986076
# Data columns (total 9 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   identifier            986077 non-null  int64
#  1   master_bol_number     986077 non-null  object
#  2   house_bol_number      433222 non-null  object
#  3   sub_house_bol_number  0 non-null       float64
#  4   voyage_number         986077 non-null  object
#  5   bill_type_code        986077 non-null  object
#  6   manifest_number       985099 non-null  float64
#  7   trade_update_date     986077 non-null  object
#  8   run_date              986077 non-null  object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 67.7+ MB

# %% [markdown]
# Columns to keep for each bill:
#
# - identifier @int
# - voyage_number @str
# - bill_type_code @str
# - manifest_number @float
# - trade_update_date @date
# - run_date @date
#
# identifier will be the primary key

# %%
cargo_desc
# Out:
#             identifier container_number  description_sequence_number  \
# 0            202001060      TEMU6512740                            1
# 1            202001061      GESU6641198                            1
# 2            202001062      OOLU1809656                            1
# 3            202001062      OOLU1809656                            2
# 4            202001062      OOLU1809656                            3
# ...                ...              ...                          ...
# 2548429  2020011458712      CSNU1142458                            1
# 2548430  2020011458713      BMOU5793090                            1
# 2548431  2020011458714      MOFU0773130                            1
# 2548432  2020011458715      CSLU2077154                            1
# 2548433  2020011458716      TCNU3464084                            1
#
#          piece_count                                   description_text
# ...

# %%
cargo_desc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2548434 entries, 0 to 2548433
# Data columns (total 5 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   identifier                   int64
#  1   container_number             object
#  2   description_sequence_number  int64
#  3   piece_count                  float64
#  4   description_text             object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 97.2+ MB

# %% [markdown]
# Columns to keep for each cargo description:
#
# - identifier @int
# - container_number @str
# - description_text @str
#
# Will probably need to generate the primary key

# %%
cosignee
# Out:
#            identifier                       consignee_name  \
# 0           202001060                     QUINTEL USA INC.
# 1           202001061                     QUINTEL USA INC.
# 2           202001062  WILLIAMS-SONOMA SINGAPORE PTE LIMIT
# 3           202001063  WILLIAMS-SONOMA SINGAPORE PTE LIMIT
# 4           202001064  WILLIAMS-SONOMA SINGAPORE PTE LIMIT
# ...               ...                                  ...
# 758989  2020011458711                    WATER MATRIX INC.
# 758990  2020011458713           INTERNATIONAL IMPORTS.,INC
# 758991  2020011458714                UNITED SUPPLY SYSTEMS
# 758992  2020011458715              MATTHEWS GRANITE CO.DBA
# 758993  2020011458716                  KUEHNE + NAGEL,INC.
#
#                         consignee_address_1              consignee_address_2  \
# 0       33300 DOWE AVE. UNION CITY, CALIFOR                  NIA, 94587, USA
# 1       33300 DOWE AVE. UNION CITY, CALIFOR                  NIA, 94587, USA
# ...

# %%
cosignee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 758994 entries, 0 to 758993
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   identifier             758994 non-null  int64
#  1   consignee_name         758994 non-null  object
#  2   consignee_address_1    758986 non-null  object
#  3   consignee_address_2    612542 non-null  object
#  4   consignee_address_3    398821 non-null  object
#  5   consignee_address_4    70670 non-null   object
#  6   city                   213829 non-null  object
#  7   state_province         183858 non-null  object
#  8   zip_code               178387 non-null  object
#  9   country_code           196224 non-null  object
#  10  contact_name           15570 non-null   object
#  11  comm_number_qualifier  154880 non-null  object
#  12  comm_number            154721 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 75.3+ MB

# %%
cosignee.identifier.unique().size
# Out:
# 748286

# %% [markdown]
# Columns to keep for each cosignee:
#
# - identifier @int
# - consignee_name @str
# - consignee_address_1 @str
# - consignee_address_2 @str
# - consignee_address_3 @str
# - consignee_address_4 @str
# - city @str
# - state_province @str
# - zip_code @str
# - country_code @str
# - contact_name @str
# - comm_number_qualifier @str
# - comm_number @str
#
# Will probably need to generate the primary key

# %%
container
# Out:
#             identifier container_number seal_number_1 seal_number_2  \
# 0            202001060      TEMU6512740      O1569143           NaN
# 1            202001061      GESU6641198      K8564655           NaN
# 2            202001062      OOLU1809656    OOLFEY3491           NaN
# 3            202001063      OOLU9729032    OOLFUB5598           NaN
# 4            202001064      OOLU9418215    OOLFUB5716           NaN
# ...                ...              ...           ...           ...
# 1572419  2020011458712      CSNU1142458      ID646888           NaN
# 1572420  2020011458713      BMOU5793090    EMCJSH1799           NaN
# 1572421  2020011458714      MOFU0773130     CNB742374           NaN
# 1572422  2020011458715      CSLU2077154       M430045           NaN
# 1572423  2020011458716      TCNU3464084           NaN           NaN
#
#                 equipment_description_code  container_length  \
# 0                         Closed Container                 0
# ...

# %%
container.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1572424 entries, 0 to 1572423
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   identifier                  1572424 non-null  int64
#  1   container_number            1572275 non-null  object
#  2   seal_number_1               1510924 non-null  object
#  3   seal_number_2               112553 non-null   object
#  4   equipment_description_code  1462839 non-null  object
#  5   container_length            1572424 non-null  int64
#  6   container_height            1572424 non-null  int64
#  7   container_width             1572424 non-null  int64
#  8   container_type              1396577 non-null  object
#  9   load_status                 1571183 non-null  object
#  10  type_of_service             1394886 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 132.0+ MB

# %%
container.container_number.unique().size
# Out:
# 892209

# %%
container['identifier_and_container_number'] = container.identifier.astype('str') + container.container_number

# %%
container.identifier_and_container_number.unique().size
# Out:
# 1572276

# %% [markdown]
# Columns to keep for each container:
#
# - identifier @int
# - container_number @str
# - equipment_description_code @str
# - container_length @int
# - container_height @int
# - container_width @int
# - container_type @str
# - load_status @str
# - type_of_service @str
#
# Will probably need to generate the primary key

# %%
hazmat
# Out:
#           identifier container_number  hazmat_sequence_number hazmat_code  \
# 0         2020010618      CMAU4677843                       1        3077
# 1         2020010619      CMAU4677843                       1        3077
# 2         2020010622      CMAU4677843                       1        1197
# 3        20200106398      BSIU2619753                       1        3288
# 4        20200106398      TGCU2139859                       1        3288
# ...              ...              ...                     ...         ...
# 34191  2020011457269      SEGU5258506                       1        2211
# 34192  2020011457269      BSIU9443795                       1        2211
# 34193  2020011457802          6931988                       1        2794
# 34194  2020011458490      SEGU8106580                       1      UN1202
# 34195  2020011458611      TCNU4728345                       1        3491
#
#       hazmat_class hazmat_code_qualifier     hazmat_contact  \
# ...

# %%
hazmat.hazmat_class.unique()
# Out:
# array([nan, '6.1', '2.1', '3', '9', '8', '5.1', '4.1', '1.4G', '2.2', '1',
#        '4.3', '2.3', '2', '5.2', '4.2', '1.3G', '1.3C', '3-07', '1.4S',
#        '1.3', '1.4', '8(3)', '7', 'F-A,', '2-10', 'F-A', '9.0', 'F-E,',
#        'III', '3(8)', '2-08', '2-04', '5.7', '3.3', '2-07', '8.0', 'F-C,',
#        'F-E', '6', '15', '3.0', 'FA-S', 'F-D,', 'F-C', '8-10', '1.1D',
#        '08'], dtype=object)

# %%
hazmat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34196 entries, 0 to 34195
# Data columns (total 12 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   identifier                                   34196 non-null  int64
#  1   container_number                             34196 non-null  object
#  2   hazmat_sequence_number                       34196 non-null  int64
#  3   hazmat_code                                  34196 non-null  object
#  4   hazmat_class                                 22798 non-null  object
#  5   hazmat_code_qualifier                        34196 non-null  object
#  6   hazmat_contact                               17152 non-null  object
#  7   hazmat_page_number                           11046 non-null  object
#  8   hazmat_flash_point_temperature               34196 non-null  object
# ...

# %% [markdown]
# Columns to keep for each hazmat:
#
# - identifier @int
# - container_number @str
# - hazmat_code @str
# - hazmat_class @str
# - hazmat_code_qualifier @str
# - hazmat_contact @str
# - hazmat_page_number @str
# - hazmat_flash_point_temperature @str
# - hazmat_flash_point_temperature_negative_ind @str
# - hazmat_flash_point_temperature_unit @str
# - hazmat_description @str
#
# Will probably need to generate the primary key

# %%
hazmat_class
# Out:
#         identifier container_number  hazmat_sequence_number  \
# 0     202001063287      TRHU3783906                       1
# 1    2020010615887      HJMU4423831                       1
# 2    2020010616465      TEMU8281785                       1
# 3    2020010626242      TCKU2355870                       1
# 4    2020010626248      TCKU2355870                       1
# ..             ...              ...                     ...
# 905  2020011551841      KOSU2213955                       4
# 906  2020011552692      SEGU7608537                       1
# 907  2020011410520      BSIU9650663                       1
# 908  2020011412827      NRSU3717097                       1
# 909  2020011458490      SEGU8106580                       1
#
#          hazmat_classification
# 0                            3
# 1                          6.1
# 2                            3
# 3                          6.1
# 4                          6.1
# ..                         ...
# ...

# %%
hazmat_class.hazmat_classification.unique()
# Out:
# array(['3', '6.1', '(2-METHYL-2-PENTENOIC ACID)',
#        '(CONTAINS BENZYL BENZOATE)', '(TRANS-2-HEXEN-1-YL ACETATE)',
#        '(TRANS-2-HEXENAL)', '(2-METHYL-3-FURANTHIOL)',
#        '(2,3-PENTANEDIONE)', '4.3', 'BATTERY FLUID, ACID', 'PG II',
#        'CORROSIVE LIQUID ACIDIC ORGANI', '2', 'CHRYSOIDINE',
#        'OCTAHYDRO TETRAMETHYL NAPHTHAL ENYL ETHANONE',
#        'CONTAINS HEXAMETHYL INDENO PYR ANE',
#        'METHACRYLIC ACID-TERT-BUTYLEST ER, STABILIZED',
#        '(2,3-HEXANEDIONE)', '(CONTAINS ETHANOL)',
#        '(2-METHOXY-3-METHYL PYRAZINE)', 'FUEL, AVIATION, TURBINE E',
#        'GASOLINE', '8', 'GAS OIL DIESEL FUEL', 'COMBUSTIBLE ENGINE', '9',
#        '3 8', 'SPRAYPAINT AEROSOLS EACH 500 M L', 'LIMONENE',
#        '1 703 527 3887', 'CHEMTREC 1 703 527 3887', '1 336 632 7745',
#        'CHEMTREC 17035273887', '1 352 323 3500 BENZ A H ANTHRACENE',
#        'METHOXYMETHANE', 'L', '12152070061', '80 ACCUMULATORS CONTAINING',
# ...

# %%
hazmat_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 910 entries, 0 to 909
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   identifier              910 non-null    int64
#  1   container_number        910 non-null    object
#  2   hazmat_sequence_number  910 non-null    int64
#  3   hazmat_classification   910 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 28.6+ KB

# %% [markdown]
# Columns to keep for each hazmat classification:
#
# - identifier @int
# - container_number @str
# - hazmat_classification @str
#
# Will probably need to generate the primary key

# %%
mark_number
# Out:
#             identifier container_number marks_and_numbers_1  \
# 0            202001060      TEMU6512740            NO MARKS
# 1            202001061      GESU6641198            NO MARKS
# 2            202001062      OOLU1809656               SKU#:
# 3            202001062      OOLU1809656                QTY:
# 4            202001062      OOLU1809656                DES:
# ...                ...              ...                 ...
# 2039499  2020011458712      CSNU1142458          NO MARKING
# 2039500  2020011458713      BMOU5793090                  BJ
# 2039501  2020011458714      MOFU0773130                 N M
# 2039502  2020011458715      CSLU2077154                  EL
# 2039503  2020011458716      TCNU3464084                   .
#
#         marks_and_numbers_2 marks_and_numbers_3 marks_and_numbers_4  \
# 0                       NaN                 NaN                 NaN
# 1                       NaN                 NaN                 NaN
# ...

# %% [markdown]
# Doesn't look like a useful table. Will exclude it for now.

# %%
notified_party
# Out:
#            identifier                    notify_party_name  \
# 0           202001062                       DAMCO USA INC.
# 1           202001062  EXPEDITORS INTERNATIONAL OF WASHING
# 2           202001063                       DAMCO USA INC.
# 3           202001063  EXPEDITORS INTERNATIONAL OF WASHING
# 4           202001064                       DAMCO USA INC.
# ...               ...                                  ...
# 760427  2020011458710                          THE WICKERY
# 760428  2020011458713           INTERNATIONAL IMPORTS.,INC
# 760429  2020011458714                J.M. RODGERS CO.,INC.
# 760430  2020011458715              MATTHEWS GRANITE CO.DBA
# 760431  2020011458716                  KUEHNE + NAGEL,INC.
#
#                      notify_party_address_1  \
# 0                     9300 ARROWPOINT BLVD.
# 1             6005 FREEPORT AVE., SUITE 102
# 2                     9300 ARROWPOINT BLVD.
# 3             6005 FREEPORT AVE., SUITE 102
# ...

# %%
notified_party.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 760432 entries, 0 to 760431
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   identifier              760432 non-null  int64
#  1   notify_party_name       760429 non-null  object
#  2   notify_party_address_1  760427 non-null  object
#  3   notify_party_address_2  674624 non-null  object
#  4   notify_party_address_3  476707 non-null  object
#  5   notify_party_address_4  97122 non-null   object
#  6   city                    149334 non-null  object
#  7   state_province          122713 non-null  object
#  8   zip_code                122881 non-null  object
#  9   country_code            131814 non-null  object
#  10  contact_name            12740 non-null   object
#  11  comm_number_qualifier   153002 non-null  object
#  12  comm_number             152940 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 75.4+ MB

# %%
notified_party.identifier.unique().size
# Out:
# 684295

# %% [markdown]
# Columns to keep for each notified party:
#
# - identifier @int
# - notify_party_name @str
# - notify_party_address_1 @str
# - notify_party_address_2 @str
# - notify_party_address_3 @str
# - notify_party_address_4 @str
# - city @str
# - state_province @str
# - zip_code @str
# - country_code @str
# - contact_name @str
# - comm_number_qualifier @str
# - comm_number @str
#
# Will probably need to generate the primary key

# %%
shipper
# Out:
#            identifier                   shipper_party_name  \
# 0           202001060   LEADTONE COMMUNICATION TECHNOLOIES
# 1           202001061  SUZHOU DONGSHAN PRECISION MANUFACTU
# 2           202001062                    DAMCO PHILIPPINES
# 3           202001063  CALFURN MANUFACTURING PHILIPPINES I
# 4           202001064  CALFURN MANUFACTURING PHILIPPINES I
# ...               ...                                  ...
# 733399  2020011458711  GUANGDONG XIANGHUA TECHNOLOGY CO.,L
# 733400  2020011458713               ANHUI LIGHT INDUSTRIES
# 733401  2020011458714          HEFEI HENGXIN ENVIRONMENTAL
# 733402  2020011458715   XIAMEN MAGIC STONE COMPANY LIMITED
# 733403  2020011458716    BRANCH OF KUEHNE+NAGEL CO.,LTD IN
#
#                     shipper_party_address_1  \
# 0       NO.8 XINHUA ROAD XINWU ZONE WUXI,JI
# 1       8 FENGHUANGSHAN RD,DONGSHAN INDUSTR
# 2       9/F ONE E-COM CENTER HARBOR DRIVE C
# 3                     MANGA ROAD PULUNGBULO
# ...

# %% [markdown]
# Columns to keep for each shipper:
#
# - identifier @int
# - shipper_name @str
# - shipper_address_1 @str
# - shipper_address_2 @str
# - shipper_address_3 @str
# - shipper_address_4 @str
# - city @str
# - state_province @str
# - zip_code @str
# - country_code @str
# - contact_name @str
# - comm_number_qualifier @str
# - comm_number @str
#
# Will probably need to generate the primary key

# %%
tariff
# Out:
#            identifier container_number  description_sequence_number  \
# 0          2020010624      BMOU5228886                            1
# 1          2020010625      DFSU6037823                            1
# 2          2020010625      OOCU7660692                            1
# 3          2020010645      CCLU4588527                            1
# 4          2020010647      SZLU9393339                            1
# ...               ...              ...                          ...
# 855885  2020011458685      TEMU9366341                            1
# 855886  2020011458685      BMOU9288651                            1
# 855887  2020011458688      DFSU2714973                            1
# 855888  2020011458690      DFSU2813106                            1
# 855889  2020011458691               NC                            1
#
#         harmonized_number  harmonized_value  harmonized_weight  \
# 0                  8451.0               0.0               6240
# ...

# %%
tariff['identifier_and_container_number'] = tariff['identifier'].astype('str') + tariff['container_number']

# %%
tariff['identifier_and_container_number'].unique().size
# Out:
# 505817

# %%
tariff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 855890 entries, 0 to 855889
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   identifier                       855890 non-null  int64
#  1   container_number                 855890 non-null  object
#  2   description_sequence_number      855890 non-null  int64
#  3   harmonized_number                781518 non-null  float64
#  4   harmonized_value                 834608 non-null  float64
#  5   harmonized_weight                855890 non-null  int64
#  6   harmonized_weight_unit           569221 non-null  object
#  7   identifier_and_container_number  855890 non-null  object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 52.2+ MB

# %% [markdown]
# Columns to keep for each tariff:
#
# - identifier @int
# - container_number @str
# - harmonized_number @float
# - harmonized_value @float
# - harmonized_weight @float
# - harmonized_weight_unit @str
#
# Will probably need to generate the primary key

# %%
container[container.container_number == 'NC']
# Out:
#             identifier container_number seal_number_1 seal_number_2  \
# 81          2020010670               NC           NaN           NaN
# 281        20200106237               NC           NaN           NaN
# 419        20200106348               NC           NaN           NaN
# 420        20200106349               NC           NaN           NaN
# 421        20200106350               NC           NaN           NaN
# ...                ...              ...           ...           ...
# 1571488  2020011458575               NC           NaN           NaN
# 1572166  2020011458647               NC           NaN           NaN
# 1572219  2020011458662               NC           NaN           NaN
# 1572388  2020011458687               NC           NaN           NaN
# 1572392  2020011458691               NC          NONE           NaN
#
#             equipment_description_code  container_length  container_height  \
# ...
