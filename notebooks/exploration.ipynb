# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
# Header tables
header = pd.read_csv('./ams/2020/202001201500/ams__header_2020__202001201500.csv', nrows=50000)
bill_info = pd.read_csv('./ams/2020/202001201500/ams__billgen_2020__202001201500.csv', nrows=50000)

# Cargo tables
cargo_desc = pd.read_csv('./ams/2020/202001201500/ams__cargodesc_2020__202001201500.csv', nrows=50000)
hazmat = pd.read_csv('./ams/2020/202001201500/ams__hazmat_2020__202001201500.csv', nrows=50000)
hazmat_class = pd.read_csv('./ams/2020/202001201500/ams__hazmatclass_2020__202001201500.csv', nrows=50000)
tariff = pd.read_csv('./ams/2020/202001201500/ams__tariff_2020__202001201500.csv', nrows=50000)

# Contact tables
cosignee = pd.read_csv('./ams/2020/202001201500/ams__consignee_2020__202001201500.csv', nrows=50000)
notified_party = pd.read_csv('./ams/2020/202001201500/ams__notifyparty_2020__202001201500.csv', nrows=50000)
shipper = pd.read_csv('./ams/2020/202001201500/ams__shipper_2020__202001201500.csv', nrows=50000)

# Container tables
container = pd.read_csv('./ams/2020/202001201500/ams__container_2020__202001201500.csv', nrows=50000)
mark_number = pd.read_csv('./ams/2020/202001201500/ams__marksnumbers_2020__202001201500.csv', nrows=50000)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (17,18,25) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
header
# Out:
#           identifier carrier_code vessel_country_code           vessel_name  \
# 0          202001060         SWOE                  US  PRESIDENT EISENHOWER
# 1          202001061         SWOE                  US  PRESIDENT EISENHOWER
# 2          202001062         OOLU                  SG       THALASSA ELPIDA
# 3          202001063         OOLU                  SG       THALASSA ELPIDA
# 4          202001064         OOLU                  TW            EVER LOYAL
# ...              ...          ...                 ...                   ...
# 49995  2020010649982         EGET                  US      YORKTOWN EXPRESS
# 49996  2020010649983         EGET                  US      YORKTOWN EXPRESS
# 49997  2020010649984         AMZD                  DE       HANOVER EXPRESS
# 49998  2020010649985         DFDS                  PA            ONE COSMOS
# 49999  2020010649986         VHFL                  DE       HANOVER EXPRESS
#
# ...

# %%
header.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 34 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   identifier                             50000 non-null  int64
#  1   carrier_code                           50000 non-null  object
#  2   vessel_country_code                    50000 non-null  object
#  3   vessel_name                            50000 non-null  object
#  4   port_of_unlading                       50000 non-null  object
#  5   estimated_arrival_date                 50000 non-null  object
#  6   foreign_port_of_lading_qualifier       50000 non-null  object
#  7   foreign_port_of_lading                 50000 non-null  object
#  8   manifest_quantity                      50000 non-null  int64
#  9   manifest_unit                          50000 non-null  object
# ...

# %% [markdown]
# The header dataset will be a part of the fact table. We will be keeping the follow columns.
#
# - identifier
# - carrier_code
# - vessel_country_code
# - vessel_name
# - port_of_unlading
# - estimated_arrival_date
# - foreign_port_of_lading_qualifier
# - foreign_port_of_lading
# - manifest_quantity
# - manifest_unit
# - weight
# - weight_unit
# - record_status_indicator
# - place_of_receipt
# - port_of_destination
# - foreign_port_of_destination_qualifier
# - foreign_port_of_destination
# - conveyance_id_qualifier
# - conveyance_id
# - mode_of_transportation
# - actual_arrival_date

# %%
bill_info
# Out:
#           identifier master_bol_number  house_bol_number  \
# 0          202001060    APLUSHBW014713  SWOESH1S01451870
# 1          202001061    APLUSHBW014714  SWOESH1S01451855
# 2          202001062    OOLU2107899100               NaN
# 3          202001063    OOLU2107932870               NaN
# 4          202001064    OOLU2107974500               NaN
# ...              ...               ...               ...
# 49995  2020010649988  ONEYNB9BQ3255700               NaN
# 49996  2020010649989  ONEYHKGVQ5814900  FLXTFCNUS669901A
# 49997  2020010649990  ONEYHAMVD9313600               NaN
# 49998  2020010649991  ONEYNB9BI4999300  CEXQ603G00645NBA
# 49999  2020010649992  ONEYNB9BI6001700  CEXQ603G00610NBC
#
#        sub_house_bol_number voyage_number bill_type_code  manifest_number  \
# 0                       NaN         0DB4P     House Bill              1.0
# 1                       NaN         0DB4P     House Bill              1.0
# ...

# %%
bill_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   identifier            50000 non-null  int64
#  1   master_bol_number     50000 non-null  object
#  2   house_bol_number      21515 non-null  object
#  3   sub_house_bol_number  0 non-null      float64
#  4   voyage_number         50000 non-null  object
#  5   bill_type_code        50000 non-null  object
#  6   manifest_number       49987 non-null  float64
#  7   trade_update_date     50000 non-null  object
#  8   run_date              50000 non-null  object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 3.4+ MB

# %% [markdown]
# The bill info dataset will be combined with the header dataset to produce the fact table. We will be keeping the following columns.
#
# - identifier
# - voyage_number
# - bill_type_code
# - manifest_number
# - trade_update_date
# - run_date

# %%
cargo_desc
# Out:
#           identifier container_number  description_sequence_number  \
# 0          202001060      TEMU6512740                            1
# 1          202001061      GESU6641198                            1
# 2          202001062      OOLU1809656                            1
# 3          202001062      OOLU1809656                            2
# 4          202001062      OOLU1809656                            3
# ...              ...              ...                          ...
# 49995  2020010619776      MSKU7056943                            1
# 49996  2020010619776      GLDU0396187                            1
# 49997  2020010619777      MAEU9165328                            1
# 49998  2020010619778      APHU7396918                            1
# 49999  2020010619778      APHU7396918                            1
#
#        piece_count                                   description_text
# 0             18.0                                            ANTENNA
# ...

# %%
cargo_desc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   identifier                   50000 non-null  int64
#  1   container_number             50000 non-null  object
#  2   description_sequence_number  50000 non-null  int64
#  3   piece_count                  33049 non-null  float64
#  4   description_text             49999 non-null  object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.9+ MB

# %% [markdown]
# The cargo description dataset will be a part of the cargo table. We will keep these columns.
#
# - identifier
# - container_number
# - description_text
# - piece_count
# - description_text

# %%
hazmat
# Out:
#           identifier container_number  hazmat_sequence_number hazmat_code  \
# 0         2020010618      CMAU4677843                       1        3077
# 1         2020010619      CMAU4677843                       1        3077
# 2         2020010622      CMAU4677843                       1        1197
# 3        20200106398      BSIU2619753                       1        3288
# 4        20200106398      TGCU2139859                       1        3288
# ...              ...              ...                     ...         ...
# 34191  2020011457269      SEGU5258506                       1        2211
# 34192  2020011457269      BSIU9443795                       1        2211
# 34193  2020011457802          6931988                       1        2794
# 34194  2020011458490      SEGU8106580                       1      UN1202
# 34195  2020011458611      TCNU4728345                       1        3491
#
#       hazmat_class hazmat_code_qualifier     hazmat_contact  \
# ...

# %%
hazmat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34196 entries, 0 to 34195
# Data columns (total 12 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   identifier                                   34196 non-null  int64
#  1   container_number                             34196 non-null  object
#  2   hazmat_sequence_number                       34196 non-null  int64
#  3   hazmat_code                                  34196 non-null  object
#  4   hazmat_class                                 22798 non-null  object
#  5   hazmat_code_qualifier                        34196 non-null  object
#  6   hazmat_contact                               17152 non-null  object
#  7   hazmat_page_number                           11046 non-null  object
#  8   hazmat_flash_point_temperature               34196 non-null  object
# ...

# %%
hazmat.hazmat_class.unique()
# Out:
# array([nan, '6.1', '2.1', '3', '9', '8', '5.1', '4.1', '1.4G', '2.2', '1',
#        '4.3', '2.3', '2', '5.2', '4.2', '1.3G', '1.3C', '3-07', '1.4S',
#        '1.3', '1.4', '8(3)', '7', 'F-A,', '2-10', 'F-A', '9.0', 'F-E,',
#        'III', '3(8)', '2-08', '2-04', '5.7', '3.3', '2-07', '8.0', 'F-C,',
#        'F-E', '6', '15', '3.0', 'FA-S', 'F-D,', 'F-C', '8-10', '1.1D',
#        '08'], dtype=object)

# %% [markdown]
# The hazmat dataset will go into the cargo dataset. And we will be keeping these columns.
#
# - identifier
# - container_number
# - hazmat_code
# - hazmat_class
# - hazmat_code_qualifier
# - hazmat_contact
# - hazmat_page_number
# - hazmat_flash_point_temperature
# - hazmat_flash_point_temperature_negative_ind
# - hazmat_flash_point_temperature_unit
# - hazmat_description

# %%
hazmat_class
# Out:
#         identifier container_number  hazmat_sequence_number  \
# 0     202001063287      TRHU3783906                       1
# 1    2020010615887      HJMU4423831                       1
# 2    2020010616465      TEMU8281785                       1
# 3    2020010626242      TCKU2355870                       1
# 4    2020010626248      TCKU2355870                       1
# ..             ...              ...                     ...
# 905  2020011551841      KOSU2213955                       4
# 906  2020011552692      SEGU7608537                       1
# 907  2020011410520      BSIU9650663                       1
# 908  2020011412827      NRSU3717097                       1
# 909  2020011458490      SEGU8106580                       1
#
#          hazmat_classification
# 0                            3
# 1                          6.1
# 2                            3
# 3                          6.1
# 4                          6.1
# ..                         ...
# ...

# %%
hazmat_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 910 entries, 0 to 909
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   identifier              910 non-null    int64
#  1   container_number        910 non-null    object
#  2   hazmat_sequence_number  910 non-null    int64
#  3   hazmat_classification   910 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 28.6+ KB

# %%
hazmat_class.hazmat_classification.unique()
# Out:
# array(['3', '6.1', '(2-METHYL-2-PENTENOIC ACID)',
#        '(CONTAINS BENZYL BENZOATE)', '(TRANS-2-HEXEN-1-YL ACETATE)',
#        '(TRANS-2-HEXENAL)', '(2-METHYL-3-FURANTHIOL)',
#        '(2,3-PENTANEDIONE)', '4.3', 'BATTERY FLUID, ACID', 'PG II',
#        'CORROSIVE LIQUID ACIDIC ORGANI', '2', 'CHRYSOIDINE',
#        'OCTAHYDRO TETRAMETHYL NAPHTHAL ENYL ETHANONE',
#        'CONTAINS HEXAMETHYL INDENO PYR ANE',
#        'METHACRYLIC ACID-TERT-BUTYLEST ER, STABILIZED',
#        '(2,3-HEXANEDIONE)', '(CONTAINS ETHANOL)',
#        '(2-METHOXY-3-METHYL PYRAZINE)', 'FUEL, AVIATION, TURBINE E',
#        'GASOLINE', '8', 'GAS OIL DIESEL FUEL', 'COMBUSTIBLE ENGINE', '9',
#        '3 8', 'SPRAYPAINT AEROSOLS EACH 500 M L', 'LIMONENE',
#        '1 703 527 3887', 'CHEMTREC 1 703 527 3887', '1 336 632 7745',
#        'CHEMTREC 17035273887', '1 352 323 3500 BENZ A H ANTHRACENE',
#        'METHOXYMETHANE', 'L', '12152070061', '80 ACCUMULATORS CONTAINING',
# ...

# %% [markdown]
# The hazmat class dataset seems to be supplementary information to the hazmat class dataset. We will be keeping the following columns.
#
# - identifier
# - container_number
# - hazmat_sequence_number

# %%
tariff
# Out:
#           identifier container_number  description_sequence_number  \
# 0         2020010624      BMOU5228886                            1
# 1         2020010625      DFSU6037823                            1
# 2         2020010625      OOCU7660692                            1
# 3         2020010645      CCLU4588527                            1
# 4         2020010647      SZLU9393339                            1
# ...              ...              ...                          ...
# 49995  2020010655169      BEAU5322202                            1
# 49996  2020010655170      KKFU7852075                            1
# 49997  2020010655171      ONEU0016071                            1
# 49998  2020010655171      TRLU9720415                            1
# 49999  2020010655172      GLDU9990271                            1
#
#        harmonized_number  harmonized_value  harmonized_weight  \
# 0                 8451.0               0.0               6240
# ...

# %%
tariff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   identifier                   50000 non-null  int64
#  1   container_number             50000 non-null  object
#  2   description_sequence_number  50000 non-null  int64
#  3   harmonized_number            45423 non-null  float64
#  4   harmonized_value             49554 non-null  float64
#  5   harmonized_weight            50000 non-null  int64
#  6   harmonized_weight_unit       26391 non-null  object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 2.7+ MB

# %% [markdown]
# The tariff dataset will be a part of the cargo table. We will be keeping the following columns.
#
# - identifier
# - container_number
# - description_sequence_number
# - harmonized_number
# - harmonized_value
# - harmonized_weight
# - harmonized_weight_unit

# %%
cosignee
# Out:
#           identifier                       consignee_name  \
# 0          202001060                     QUINTEL USA INC.
# 1          202001061                     QUINTEL USA INC.
# 2          202001062  WILLIAMS-SONOMA SINGAPORE PTE LIMIT
# 3          202001063  WILLIAMS-SONOMA SINGAPORE PTE LIMIT
# 4          202001064  WILLIAMS-SONOMA SINGAPORE PTE LIMIT
# ...              ...                                  ...
# 49995  2020010665890               EMPRESAS BERRIOS, INC.
# 49996  2020010665891       CENTENO TIRE DISTRIBUTORS INC.
# 49997  2020010665892                      CASA FEBUS INC.
# 49998  2020010665893                    ECU WORLDWIDE USA
# 49999  2020010665894                  MAGIC TRANSPORT INC
#
#                        consignee_address_1  \
# 0      33300 DOWE AVE. UNION CITY, CALIFOR
# 1      33300 DOWE AVE. UNION CITY, CALIFOR
# 2                           7755 POLK LANE
# 3                           7755 POLK LANE
# 4                           7755 POLK LANE
# ...

# %%
cosignee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   identifier             50000 non-null  int64
#  1   consignee_name         50000 non-null  object
#  2   consignee_address_1    50000 non-null  object
#  3   consignee_address_2    40884 non-null  object
#  4   consignee_address_3    27477 non-null  object
#  5   consignee_address_4    5197 non-null   object
#  6   city                   13844 non-null  object
#  7   state_province         11950 non-null  object
#  8   zip_code               11504 non-null  object
#  9   country_code           12502 non-null  object
#  10  contact_name           728 non-null    object
#  11  comm_number_qualifier  9297 non-null   object
#  12  comm_number            9296 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 5.0+ MB

# %%
notified_party
# Out:
#           identifier                    notify_party_name  \
# 0          202001062                       DAMCO USA INC.
# 1          202001062  EXPEDITORS INTERNATIONAL OF WASHING
# 2          202001063                       DAMCO USA INC.
# 3          202001063  EXPEDITORS INTERNATIONAL OF WASHING
# 4          202001064                       DAMCO USA INC.
# ...              ...                                  ...
# 49995  2020010665039    LUPA FOODS LTD SUITE A31, ELSTREE
# 49996  2020010665040                     ACC SHIPPING LTD
# 49997  2020010665041                        ESSITY UK LTD
# 49998  2020010665042                     ACC SHIPPING LTD
# 49999  2020010665043                        ESSITY UK LTD
#
#                    notify_party_address_1          notify_party_address_2  \
# 0                   9300 ARROWPOINT BLVD.                    CHARLOTTE NC
# 1           6005 FREEPORT AVE., SUITE 102                      MEMPHIS TN
# ...

# %%
notified_party.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   identifier              50000 non-null  int64
#  1   notify_party_name       50000 non-null  object
#  2   notify_party_address_1  50000 non-null  object
#  3   notify_party_address_2  45001 non-null  object
#  4   notify_party_address_3  32693 non-null  object
#  5   notify_party_address_4  6801 non-null   object
#  6   city                    10041 non-null  object
#  7   state_province          8291 non-null   object
#  8   zip_code                8198 non-null   object
#  9   country_code            8659 non-null   object
#  10  contact_name            452 non-null    object
#  11  comm_number_qualifier   9533 non-null   object
#  12  comm_number             9533 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 5.0+ MB

# %%
shipper
# Out:
#           identifier                   shipper_party_name  \
# 0          202001060   LEADTONE COMMUNICATION TECHNOLOIES
# 1          202001061  SUZHOU DONGSHAN PRECISION MANUFACTU
# 2          202001062                    DAMCO PHILIPPINES
# 3          202001063  CALFURN MANUFACTURING PHILIPPINES I
# 4          202001064  CALFURN MANUFACTURING PHILIPPINES I
# ...              ...                                  ...
# 49995  2020010667548    M. DIAS BRANCO S/A IND. E COM. DE
# 49996  2020010667550                 CERAMICA GOMEZ, S.A.
# 49997  2020010667551                 KERABEN GRUPO S.A.U.
# 49998  2020010667552    ECOCERAMIC, CERAMIC TILE INTL SLU
# 49999  2020010667553                   TEJAS BORJA, S.A.U
#
#                    shipper_party_address_1         shipper_party_address_2  \
# 0      NO.8 XINHUA ROAD XINWU ZONE WUXI,JI                           ANGSU
# 1      8 FENGHUANGSHAN RD,DONGSHAN INDUSTR                        IAL PART
# ...

# %%
shipper.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   identifier               50000 non-null  int64
#  1   shipper_party_name       50000 non-null  object
#  2   shipper_party_address_1  50000 non-null  object
#  3   shipper_party_address_2  42991 non-null  object
#  4   shipper_party_address_3  32268 non-null  object
#  5   shipper_party_address_4  6106 non-null   object
#  6   city                     14189 non-null  object
#  7   state_province           3936 non-null   object
#  8   zip_code                 5965 non-null   object
#  9   country_code             13308 non-null  object
#  10  contact_name             1062 non-null   object
#  11  comm_number_qualifier    9896 non-null   object
#  12  comm_number              9892 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 5.0+ MB

# %% [markdown]
# All the contact datasets have consistent schemas. We will be combining them and adding the type column. We will keep all the columns

# %%
container
# Out:
#           identifier container_number seal_number_1 seal_number_2  \
# 0          202001060      TEMU6512740      O1569143           NaN
# 1          202001061      GESU6641198      K8564655           NaN
# 2          202001062      OOLU1809656    OOLFEY3491           NaN
# 3          202001063      OOLU9729032    OOLFUB5598           NaN
# 4          202001064      OOLU9418215    OOLFUB5716           NaN
# ...              ...              ...           ...           ...
# 49995  2020010631226               NC           NaN           NaN
# 49996  2020010631227      UACU8524608       8649262    HLD8649262
# 49997  2020010631228      DFSU6601131        042254           NaN
# 49998  2020010631229      CAIU8954732        073874           NaN
# 49999  2020010631230      TCNU4049468        066769           NaN
#
#       equipment_description_code  container_length  container_height  \
# 0               Closed Container                 0                 0
# ...

# %%
container.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   identifier                  50000 non-null  int64
#  1   container_number            50000 non-null  object
#  2   seal_number_1               49335 non-null  object
#  3   seal_number_2               3132 non-null   object
#  4   equipment_description_code  48687 non-null  object
#  5   container_length            50000 non-null  int64
#  6   container_height            50000 non-null  int64
#  7   container_width             50000 non-null  int64
#  8   container_type              44945 non-null  object
#  9   load_status                 49999 non-null  object
#  10  type_of_service             46114 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 4.2+ MB

# %% [markdown]
# The container dataset will be the majority part of the container table. We will be keeping the following columns.
#
# - identifier
# - container_number
# - equipment_description_code
# - container_length
# - container_height
# - container_width
# - container_type
# - load_status
# - type_of_service

# %%
mark_number
# Out:
#           identifier container_number  \
# 0          202001060      TEMU6512740
# 1          202001061      GESU6641198
# 2          202001062      OOLU1809656
# 3          202001062      OOLU1809656
# 4          202001062      OOLU1809656
# ...              ...              ...
# 49995  2020010623909      TCNU5071126
# 49996  2020010623910      CAIU9569828
# 49997  2020010623911      SEGU4056769
# 49998  2020010623912      BSIU2270321
# 49999  2020010623913      GESU5858511
#
#                                  marks_and_numbers_1 marks_and_numbers_2  \
# 0                                           NO MARKS                 NaN
# 1                                           NO MARKS                 NaN
# 2                                              SKU#:             4960113
# 3                                               QTY:             MADE IN
# 4                                               DES:         BOTTLEBRUSH
# ...

# %%
mark_number.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   identifier           50000 non-null  int64
#  1   container_number     50000 non-null  object
#  2   marks_and_numbers_1  49644 non-null  object
#  3   marks_and_numbers_2  26508 non-null  object
#  4   marks_and_numbers_3  21524 non-null  object
#  5   marks_and_numbers_4  18632 non-null  object
#  6   marks_and_numbers_5  16513 non-null  object
#  7   marks_and_numbers_6  14935 non-null  object
#  8   marks_and_numbers_7  13631 non-null  object
#  9   marks_and_numbers_8  12673 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 3.8+ MB

# %% [markdown]
# The mark number dataset will complement the container table. We will keep all the columns.

# %% [markdown]
# We will not be filling in any missing value because it's no way to appropriately do so and those values might be missing for a reason. We will keep the original data for the most parts.
